# %%
# example of loading the keras facenet model
from keras.models import load_model
# load the model
model = load_model('./models/facenet_keras.h5', compile=False)
# summarize input and output shape
print(model.inputs)
print(model.outputs)
# Out:
# Using TensorFlow backend.
# [<tf.Tensor 'input_1:0' shape=(None, 160, 160, 3) dtype=float32>]
# [<tf.Tensor 'Bottleneck_BatchNorm/cond/Identity:0' shape=(None, 128) dtype=float32>]

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN

# extract a single face from a given photograph
def extract_face(filename, required_size=(160, 160)):
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		# get face
		face = extract_face(path)
		# store
		faces.append(face)
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
	return asarray(X), asarray(y)

# load train dataset
trainX, trainy = load_dataset('../data/lfw/')
print(trainX.shape, trainy.shape)
# load test dataset
testX, testy = load_dataset('../data/lfw/')
# save arrays to one file in compressed format
savez_compressed('celebrity-faces-dataset.npz', trainX, trainy, testX, testy)
# Out:
# >loaded 1 examples for class: Bilal_Erdogan
# >loaded 1 examples for class: David_Tornberg
# >loaded 10 examples for class: Richard_Gere
# >loaded 1 examples for class: Marc_Anthony
# >loaded 1 examples for class: Jean-Marc_Olive
# >loaded 6 examples for class: Christine_Todd_Whitman
# >loaded 1 examples for class: Robert_Weitzel
# >loaded 1 examples for class: Carlos_Fasciolo
# >loaded 1 examples for class: Sally_Clark
# >loaded 1 examples for class: Pablo_Latras
# >loaded 1 examples for class: Tex_Ritter
# >loaded 1 examples for class: Sarah_Canale
# >loaded 1 examples for class: Rick_Bragg
# >loaded 5 examples for class: Kevin_Spacey
# >loaded 1 examples for class: James_Sensenbrenner
# >loaded 2 examples for class: Olivia_Newton-John
# >loaded 1 examples for class: Fatmir_Limaj
# >loaded 5 examples for class: Sean_OKeefe
# >loaded 1 examples for class: Queen_Noor
# >loaded 1 examples for class: Bill_Herrion
# >loaded 2 examples for class: Charles_Grassley
# >loaded 4 examples for class: Angelo_Reyes
# >loaded 1 examples for class: Laura_Marlow
# >loaded 2 examples for class: Nasser_al-Kidwa
# >loaded 1 examples for class: Paige_Fitzgerald
# >loaded 1 examples for class: Chelsea_Clinton
# >loaded 1 examples for class: Mike_Fisher
# >loaded 3 examples for class: Eric_Robert_Rudolph
# >loaded 1 examples for class: John_Moxley
# >loaded 1 examples for class: Yolanda_King
# >loaded 1 examples for class: Deniz_Baykal
# >loaded 1 examples for class: Urmila_Matondkar
# >loaded 1 examples for class: Mark_Mishkin
# >loaded 1 examples for class: Gary_Condit
# >loaded 1 examples for class: Patsy_Hardy
# >loaded 1 examples for class: Sylvia_Plachy
# >loaded 1 examples for class: Roberto_Lavagna
# >loaded 2 examples for class: Marcus_Gronholm
# >loaded 1 examples for class: Regina_Ip
# >loaded 2 examples for class: Raymond_Odierno
# >loaded 3 examples for class: Kristen_Breitweiser
# >loaded 1 examples for class: John_Cornyn
# >loaded 1 examples for class: Bill_Byrne
# >loaded 1 examples for class: Vassilis_Xiros
# >loaded 1 examples for class: Wanda_de_la_Jesus
# >loaded 3 examples for class: James_Traficant
# >loaded 1 examples for class: Daniel_Barenboim
# >loaded 1 examples for class: Michelle_Bachelet
# >loaded 1 examples for class: Eric_Dubin
# >loaded 7 examples for class: Oscar_De_La_Hoya
# >loaded 1 examples for class: Mark_Swartz
# >loaded 1 examples for class: Mario_Vasquez_Rana
# >loaded 2 examples for class: Guillermo_Ortiz
# >loaded 1 examples for class: Shannyn_Sossamon
# >loaded 1 examples for class: Pedro_Pauleta
# >loaded 1 examples for class: John_Franco
# >loaded 1 examples for class: Dorothy_Loudon
# >loaded 2 examples for class: Janet_Thorpe
# >loaded 2 examples for class: Paul_Byrd
# >loaded 1 examples for class: Josh_Kronfeld
# >loaded 1 examples for class: Mary_Anne_Souza
# >loaded 1 examples for class: Mark_McClellan
# >loaded 1 examples for class: Michelle_Chiklis
# >loaded 1 examples for class: Allan_Wagner
# >loaded 2 examples for class: Diane_Green
# >loaded 2 examples for class: John_F_Kennedy_Jr
# >loaded 1 examples for class: Brandon_Jones
# >loaded 1 examples for class: Jaromir_Jagr
# >loaded 1 examples for class: Marisol_Martinez_Sambran
# >loaded 1 examples for class: Ali_Hammoud
# >loaded 10 examples for class: Paradorn_Srichaphan
# >loaded 2 examples for class: Jeffrey_Archer
# >loaded 49 examples for class: Vladimir_Putin
# >loaded 21 examples for class: Jennifer_Lopez
# >loaded 1 examples for class: Daniel_Ortega
# >loaded 2 examples for class: Johnny_Carson
# >loaded 2 examples for class: Mark_Warner
# >loaded 1 examples for class: Adam_Mair
# >loaded 1 examples for class: Ian_Campbell
# >loaded 1 examples for class: Connie_Chung
# >loaded 1 examples for class: Pier_Ferdinando_Casini
# >loaded 6 examples for class: Dennis_Hastert
# >loaded 1 examples for class: Ana_Isabel_Sanchez
# >loaded 3 examples for class: Anibal_Ibarra
# >loaded 1 examples for class: David_Scott_Morris
# >loaded 1 examples for class: Charley_Armey
# >loaded 3 examples for class: Stanley_McChrystal
# >loaded 1 examples for class: Mark_Everson
# >loaded 1 examples for class: Jorge_Moreno
# >loaded 1 examples for class: Philip_Zalewski
# >loaded 1 examples for class: Wilfredo_Moreno
# >loaded 1 examples for class: Ashley_Judd
# >loaded 1 examples for class: Tammy_Helm
# >loaded 1 examples for class: Cosmo_Iacavazzi
# >loaded 1 examples for class: Marion_Fahnestock
# >loaded 3 examples for class: James_Caan
# >loaded 1 examples for class: Maurice_Papon
# >loaded 2 examples for class: Patrick_Ewing
# >loaded 1 examples for class: Roger_Cook
# >loaded 1 examples for class: Karen_Allen
# >loaded 3 examples for class: Rick_Stansbury
# >loaded 2 examples for class: Jim_Harrick
# >loaded 1 examples for class: Robert_Wiener
# >loaded 4 examples for class: Derek_Jeter
# >loaded 9 examples for class: Bill_Frist
# >loaded 1 examples for class: Alina_Kabaeva
# >loaded 1 examples for class: David_Gest
# >loaded 1 examples for class: Janez_Drnovsek
# >loaded 10 examples for class: Tommy_Thompson
# >loaded 1 examples for class: Philippe_Gagnon
# >loaded 1 examples for class: Tim_Howard
# >loaded 1 examples for class: Aby_Har-Even
# >loaded 3 examples for class: Adolfo_Aguilar_Zinser
# >loaded 2 examples for class: Robert_Witt
# >loaded 5 examples for class: Heidi_Klum
# >loaded 1 examples for class: Shane_Phillips
# >loaded 1 examples for class: Dan_Snyder
# >loaded 1 examples for class: Dominick_Dunne
# >loaded 1 examples for class: David_Sibleyk
# >loaded 2 examples for class: Courtney_Love
# >loaded 1 examples for class: Kim_Su_Nam
# >loaded 1 examples for class: Johannes_Rau
# >loaded 2 examples for class: Mike_Helton
# >loaded 1 examples for class: David_Siegel
# >loaded 1 examples for class: Scott_Fawell
# >loaded 1 examples for class: Don_Flanagan
# >loaded 7 examples for class: Ana_Guevara
# >loaded 1 examples for class: Mark_Martin
# >loaded 3 examples for class: Prince_Harry
# >loaded 1 examples for class: Lucia_Kenny_Anthony
# >loaded 15 examples for class: Pierce_Brosnan
# >loaded 1 examples for class: Estella_Warren
# >loaded 1 examples for class: Henning_Scherf
# >loaded 1 examples for class: Eduardo_Romero
# >loaded 1 examples for class: Peter_Schultz
# >loaded 2 examples for class: Lauren_Killian
# >loaded 1 examples for class: Derek_King
# >loaded 1 examples for class: Kevin_Hearn
# >loaded 1 examples for class: Ivan_Stambolic
# >loaded 1 examples for class: Suh_Chung-won
# >loaded 1 examples for class: Ian_Gillan
# >loaded 1 examples for class: Roman_Coppola
# >loaded 7 examples for class: Amelia_Vega
# >loaded 6 examples for class: Calista_Flockhart
# >loaded 3 examples for class: James_Cunningham
# >loaded 1 examples for class: Scott_Gorelick
# >loaded 15 examples for class: Hu_Jintao
# >loaded 1 examples for class: Princess_Victoria
# >loaded 1 examples for class: Javier_Vazquez
# >loaded 1 examples for class: Paulina_Rodriguez_Davila
# >loaded 2 examples for class: Charlie_Zaa
# >loaded 1 examples for class: Phillips_Idowu
# >loaded 2 examples for class: Denise_Johnson
# >loaded 1 examples for class: Francisco_Maturana
# >loaded 2 examples for class: Munir_Akram
# >loaded 1 examples for class: Bill_Fennelly
# >loaded 1 examples for class: Timothy_Wirth
# >loaded 1 examples for class: Brian_Grazier
# >loaded 1 examples for class: John_Geoghan
# >loaded 3 examples for class: Bill_Callahan
# >loaded 1 examples for class: Paul_Desmarais
# >loaded 1 examples for class: Einars_Repse
# >loaded 1 examples for class: Franklin_Damann
# >loaded 2 examples for class: Brooke_Shields
# >loaded 1 examples for class: Thad_Matta
# >loaded 1 examples for class: Phil_Morris
# >loaded 2 examples for class: Princess_Aiko
# >loaded 1 examples for class: Glenn_Tilton
# >loaded 1 examples for class: Carlos_Beltran
# >loaded 3 examples for class: Kelvin_Sampson
# >loaded 1 examples for class: Michael_Brandon
# >loaded 1 examples for class: Gwen_Stefani
# >loaded 1 examples for class: Benicio_Del_Toro
# >loaded 1 examples for class: John_Engler
# >loaded 1 examples for class: Irene_Kahn
# >loaded 2 examples for class: Alimzhan_Tokhtakhounov
# >loaded 2 examples for class: David_Caraway
# >loaded 1 examples for class: Kellie_Coffey
# >loaded 2 examples for class: Martin_Cauchon
# >loaded 1 examples for class: Carlos_Savedra
# >loaded 2 examples for class: Robert_Horan
# >loaded 4 examples for class: Herb_Sendek
# >loaded 4 examples for class: Christine_Gregoire
# >loaded 3 examples for class: Emmanuelle_Beart
# >loaded 1 examples for class: Scott_Verplank
# >loaded 1 examples for class: Mike_Alden
# >loaded 3 examples for class: Marieta_Chrousala
# >loaded 1 examples for class: Ilie_Nastase
# >loaded 4 examples for class: George_Ryan
# >loaded 1 examples for class: Kai-Uwe_Ricke
# >loaded 1 examples for class: Micky_Ward
# >loaded 1 examples for class: John_Lisowski
# >loaded 1 examples for class: Fredric_Seaman
# >loaded 2 examples for class: Michael_Leavitt
# >loaded 8 examples for class: Ana_Palacio
# >loaded 1 examples for class: Raul_Gonzalez
# >loaded 1 examples for class: Joe_Glover
# >loaded 4 examples for class: Art_Howe
# >loaded 13 examples for class: Gordon_Brown
# >loaded 11 examples for class: Ann_Veneman
# >loaded 1 examples for class: Toutai_Kefu
# >loaded 1 examples for class: Alexandre_Daigle
# >loaded 1 examples for class: Gerry_Kelly
# >loaded 1 examples for class: Larry_Pleau
# >loaded 1 examples for class: Sid_Caesar
# >loaded 2 examples for class: Lim_Dong-won
# >loaded 1 examples for class: Gus_Frerotte
# >loaded 1 examples for class: Christopher_Speer
# >loaded 1 examples for class: Jim_Greenwood
# >loaded 1 examples for class: Dalia_Rabin-Pelosoff
# >loaded 1 examples for class: Karen_Clarkson
# >loaded 1 examples for class: Yogi_Berra
# >loaded 1 examples for class: William_Perry
# >loaded 1 examples for class: Kweisi_Mfume
# >loaded 1 examples for class: Nathan_Powell
# >loaded 2 examples for class: Hayley_Tullett
# >loaded 5 examples for class: Elizabeth_Hurley
# >loaded 2 examples for class: Minnie_Driver
# >loaded 1 examples for class: Kristin_Scott_Thomas
# >loaded 3 examples for class: Martin_Verkerk
# >loaded 1 examples for class: Jim_Zorn
# >loaded 5 examples for class: Brad_Johnson
# >loaded 1 examples for class: Joe_Darrell
# >loaded 1 examples for class: Paul_Otellini
# >loaded 1 examples for class: Herman_Edwards
# >loaded 2 examples for class: Margaret_Thatcher
# >loaded 144 examples for class: Tony_Blair
# >loaded 2 examples for class: Chris_Rock
# >loaded 1 examples for class: Kevin_Keegan
# >loaded 1 examples for class: Claire_Tomalin
# >loaded 1 examples for class: Roberto_Robaina
# >loaded 1 examples for class: Roland_Koch
# >loaded 1 examples for class: Manuel_Rosendo
# >loaded 1 examples for class: Norman_Mailer
# >loaded 1 examples for class: Richard_Levin
# >loaded 2 examples for class: Leonard_Hamilton
# >loaded 5 examples for class: Ai_Sugiyama
# >loaded 1 examples for class: Darlene_Garrettson
# >loaded 1 examples for class: Kang_Gum-sil
# >loaded 1 examples for class: Mark_Salter
# >loaded 1 examples for class: Anne_Cavers
# >loaded 3 examples for class: Salman_Rushdie
# >loaded 1 examples for class: James_Murdoch
# >loaded 1 examples for class: David_Hasselhoff
# >loaded 1 examples for class: Joe_Paterno
# >loaded 1 examples for class: Abdullah_Nasseef
# >loaded 2 examples for class: Ishaq_Shahryar
# >loaded 2 examples for class: David_Myers
# >loaded 1 examples for class: Mario_Alfaro-Lopez
# >loaded 1 examples for class: Horacio_Julio_Pina
# >loaded 1 examples for class: Luo_Linquan
# >loaded 2 examples for class: George_Roy_Hill
# >loaded 1 examples for class: Riek_Blanjaar
# >loaded 3 examples for class: Wu_Yi
# >loaded 4 examples for class: Mikhail_Kasyanov
# >loaded 1 examples for class: Chris_Swecker
# >loaded 1 examples for class: Ramon_Ponce_de_Leon
# >loaded 1 examples for class: Brandon_Spann
# >loaded 1 examples for class: Adam_Kennedy
# >loaded 1 examples for class: Ornella_Muti
# >loaded 5 examples for class: Denzel_Washington
# >loaded 1 examples for class: Jorge_Alberto_Galindo
# >loaded 5 examples for class: Ludivine_Sagnier
# >loaded 1 examples for class: Monique_Ferreira
# >loaded 1 examples for class: Brennon_Leighton
# >loaded 1 examples for class: Jim_Ahern
# >loaded 1 examples for class: Lester_Holt
# >loaded 1 examples for class: Hector_Grullon
# >loaded 1 examples for class: Sandra_Ceccarelli
# >loaded 2 examples for class: Diana_Taurasi
# >loaded 3 examples for class: Patti_Labelle
# >loaded 1 examples for class: Spike_Jonze
# >loaded 1 examples for class: Eliza_Dushku
# >loaded 1 examples for class: Bob_Riley
# >loaded 1 examples for class: Hernan_Crespo
# >loaded 1 examples for class: Shamai_Leibowitz
# >loaded 1 examples for class: Faye_Alibocus
# >loaded 1 examples for class: Imran_Khan
# >loaded 12 examples for class: Harrison_Ford
# >loaded 11 examples for class: Sergey_Lavrov
# >loaded 1 examples for class: Jenna_Elfman
# >loaded 1 examples for class: Niall_Connolly
# >loaded 2 examples for class: Garry_Trudeau
# >loaded 1 examples for class: John_Richardson
# >loaded 1 examples for class: Tomas_Enge
# >loaded 1 examples for class: Aidan_Quinn
# >loaded 1 examples for class: Michael_Kors
# >loaded 1 examples for class: Lonnie_Donegan
# >loaded 1 examples for class: Anna_Jones
# >loaded 1 examples for class: Osrat_Iosef
# >loaded 2 examples for class: Aitor_Gonzalez
# >loaded 1 examples for class: Rafael_Vinoly
# >loaded 1 examples for class: Suzanne_Torrance
# >loaded 1 examples for class: Peter_Ueberroth
# >loaded 1 examples for class: Anette_Hosoi
# >loaded 2 examples for class: Jose_Dirceu
# >loaded 1 examples for class: Rocco_Buttiglione
# >loaded 1 examples for class: Yekaterina_Guseva
# >loaded 2 examples for class: James_Parker
# >loaded 1 examples for class: Emyr_Jones_Parry
# >loaded 1 examples for class: Billy_Bob_Thornton
# >loaded 1 examples for class: Chyung_Dai-chul
# >loaded 3 examples for class: Norodom_Sihanouk
# >loaded 1 examples for class: Larry_Hagman
# >loaded 1 examples for class: Jimmy_Jimenez
# >loaded 1 examples for class: Takaloo
# >loaded 1 examples for class: Dave_McGinnis
# >loaded 1 examples for class: Mehdi_Baala
# >loaded 1 examples for class: Mark_Andrew
# >loaded 4 examples for class: Erin_Runnion
# >loaded 1 examples for class: Anthony_Corso
# >loaded 1 examples for class: Jesus_Cardenal
# >loaded 2 examples for class: Howard_Schultz
# >loaded 26 examples for class: Rudolph_Giuliani
# >loaded 1 examples for class: Penelope_Taylor
# >loaded 1 examples for class: Luther_Htu
# >loaded 1 examples for class: Emily_Stevens
# >loaded 1 examples for class: Peter_Max
# >loaded 1 examples for class: Robert_Pollack
# >loaded 1 examples for class: Amanda_Marsh
# >loaded 1 examples for class: Eric_Lloyd
# >loaded 1 examples for class: Millicent_Martin
# >loaded 1 examples for class: Paul_Tracy
# >loaded 2 examples for class: Ismail_Merchant
# >loaded 1 examples for class: Patrick_Clawsen
# >loaded 55 examples for class: Jean_Chretien
# >loaded 2 examples for class: Wesley_Clark
# >loaded 1 examples for class: Peter_Care
# >loaded 1 examples for class: Randy_Dryer
# >loaded 2 examples for class: Thomas_Bjorn
# >loaded 1 examples for class: Kristin_Chenoweth
# >loaded 1 examples for class: Jose_Alencar
# >loaded 1 examples for class: Matt_Siebrandt
# >loaded 2 examples for class: William_Burns
# >loaded 1 examples for class: Ann_Godbehere
# >loaded 1 examples for class: Erin_Hershey_Presley
# >loaded 1 examples for class: Nick_Cassavetes
# >loaded 1 examples for class: Ridley_Scott
# >loaded 1 examples for class: Brock_Berlin
# >loaded 1 examples for class: Kimberly_Bruckner
# >loaded 2 examples for class: Jorge_Rodolfo_Canicoba_Corral
# >loaded 1 examples for class: Masaru_Hayami
# >loaded 4 examples for class: Jennifer_Connelly
# >loaded 1 examples for class: Brian_Kerr
# >loaded 3 examples for class: Lynne_Cheney
# >loaded 1 examples for class: Julia_Ormond
# >loaded 1 examples for class: Jim_Jeffords
# >loaded 2 examples for class: Surakait_Sathirathai
# >loaded 1 examples for class: John_Hartson
# >loaded 2 examples for class: Mike_Price
# >loaded 1 examples for class: Cristiano_da_Matta
# >loaded 1 examples for class: Wayne_Newton
# >loaded 1 examples for class: Anthony_Garotinho
# >loaded 1 examples for class: Felipe_Fernandez
# >loaded 3 examples for class: Juan_Ignacio_Chela
# >loaded 1 examples for class: Bernadette_Peters
# >loaded 4 examples for class: Pupi_Avati
# >loaded 4 examples for class: Anders_Fogh_Rasmussen
# >loaded 1 examples for class: Melissa_Stark
# >loaded 1 examples for class: Leigh_Winchell
# >loaded 1 examples for class: Qian_Qichen
# >loaded 2 examples for class: Lisa_Gottsegen
# >loaded 1 examples for class: Irv_Nathan
# >loaded 4 examples for class: Mike_Tyson
# >loaded 1 examples for class: Liliana_Cavani
# >loaded 1 examples for class: Derek_Parra
# >loaded 1 examples for class: Jose_Vicente_Rangel
# >loaded 1 examples for class: James_Barksdale
# >loaded 9 examples for class: Jeong_Se-hyun
# >loaded 2 examples for class: Ahmad_Masood
# >loaded 1 examples for class: Brandon_Fails
# >loaded 1 examples for class: Walter_Woods
# >loaded 1 examples for class: Ekaterina_Dmitriev
# >loaded 1 examples for class: Daniele_Nardello
# >loaded 1 examples for class: Lin_Yi-fu
# >loaded 1 examples for class: Natalia_Vodonova
# >loaded 1 examples for class: Yoshiyuki_Kamei
# >loaded 2 examples for class: Elinor_Caplan
# >loaded 1 examples for class: Helen_Alvare
# >loaded 1 examples for class: Eric_Ryan_Donnelly
# >loaded 4 examples for class: Mian_Khursheed_Mehmood_Kasuri
# >loaded 3 examples for class: Jose_Canseco
# >loaded 1 examples for class: Ashley_Postell
# >loaded 1 examples for class: Carina_Lau_Ka-ling
# >loaded 1 examples for class: Alicia_Hollowell
# >loaded 1 examples for class: Ralph_Friedgen
# >loaded 1 examples for class: Kelly_Osbourne
# >loaded 2 examples for class: Billy_Graham
# >loaded 1 examples for class: Sue_Grafton
# >loaded 1 examples for class: Paul_Luvera
# >loaded 1 examples for class: Shavon_Earp
# >loaded 2 examples for class: Jefferson_Perez
# >loaded 1 examples for class: Garry_McCoy
# >loaded 1 examples for class: Christian_Olsson
# >loaded 1 examples for class: Dino_Risi
# >loaded 1 examples for class: Jim_Wall
# >loaded 1 examples for class: Gustavo_Terrazas
# >loaded 1 examples for class: Willie_Nelson
# >loaded 1 examples for class: Joe_DeLamielleure
# >loaded 1 examples for class: Infanta_Cristina
# >loaded 1 examples for class: Gerald_Riley
# >loaded 1 examples for class: Mark_Mariscal
# >loaded 4 examples for class: Abel_Pacheco
# >loaded 1 examples for class: Kristy_Curry
# >loaded 1 examples for class: Greg_Frers
# >loaded 1 examples for class: Stacey_Jones
# >loaded 1 examples for class: Aram_Adler
# >loaded 1 examples for class: Gene_Keady
# >loaded 1 examples for class: Kellie_Greene
# >loaded 1 examples for class: Cynthia_Nixon
# >loaded 1 examples for class: Edward_Egan
# >loaded 1 examples for class: Joaquim_Rodriguez
# >loaded 1 examples for class: Benjamin_Franklin
# >loaded 2 examples for class: William_Martin
# >loaded 1 examples for class: Melinda_Czink
# >loaded 1 examples for class: Markus_Beyer
# >loaded 4 examples for class: Bob_Huggins
# >loaded 1 examples for class: Janet_Ecker
# >loaded 2 examples for class: Jack_Grubman
# >loaded 2 examples for class: Michael_Capellas
# >loaded 1 examples for class: Kirsten_Gilham
# >loaded 1 examples for class: Kurt_Schottenheimer
# >loaded 1 examples for class: Tom_Smothers
# >loaded 6 examples for class: Susan_Sarandon
# >loaded 1 examples for class: Larry_Flynt
# >loaded 1 examples for class: Gavyn_Arthur
# >loaded 1 examples for class: Stacey_Dales-Schuman
# >loaded 1 examples for class: Ray_Liotta
# >loaded 1 examples for class: Mikhail_Khodorkovsky
# >loaded 1 examples for class: Fabian_Vargas
# >loaded 1 examples for class: David_Bowie
# >loaded 4 examples for class: Daniel_Radcliffe
# >loaded 1 examples for class: Turner_Stevenson
# >loaded 2 examples for class: Tracy_McGrady
# >loaded 1 examples for class: Griffin_Colvin
# >loaded 1 examples for class: Mona_Rishmawi
# >loaded 1 examples for class: Mickey_Rooney
# >loaded 1 examples for class: Ataollah_Mohajerani
# >loaded 1 examples for class: Elena_Dementieva
# >loaded 1 examples for class: Kent_McCord
# >loaded 1 examples for class: Jackie_Sherrill
# >loaded 1 examples for class: Diana_Silvius
# >loaded 1 examples for class: Fatma_Kusibeh
# >loaded 6 examples for class: Boris_Becker
# >loaded 3 examples for class: Paul_Shanley
# >loaded 2 examples for class: Ellen_DeGeneres
# >loaded 1 examples for class: Zara_Akhmadova
# >loaded 1 examples for class: Chris_Klein
# >loaded 1 examples for class: Miranda_Otto
# >loaded 5 examples for class: Michael_Powell
# >loaded 1 examples for class: Miguel_Rosseto
# >loaded 1 examples for class: Colleen_Jones
# >loaded 1 examples for class: Ajit_Agarkar
# >loaded 1 examples for class: Gabrielle_Union
# >loaded 1 examples for class: Luis_Rosario_Huertas
# >loaded 8 examples for class: John_Edwards
# >loaded 5 examples for class: Steffi_Graf
# >loaded 1 examples for class: Frank_Wycheck
# >loaded 1 examples for class: Karin_Pilsaeter
# >loaded 2 examples for class: Raquel_Welch
# >loaded 1 examples for class: Zeng_Qinghong
# >loaded 1 examples for class: Ascencion_Barajas
# >loaded 1 examples for class: Eric_Vigouroux
# >loaded 3 examples for class: Edwin_Edwards
# >loaded 2 examples for class: Karin_Stoiber
# >loaded 5 examples for class: Martina_McBride
# >loaded 1 examples for class: Marcos_Daniel_Jimenez
# >loaded 1 examples for class: Bryan_Adams
# >loaded 1 examples for class: Jose_Miguel_Aleman
# >loaded 1 examples for class: Nicklas_Lidstrom
# >loaded 1 examples for class: Lokendra_Bahadur_Chand
# >loaded 1 examples for class: Galen_Rowell
# >loaded 19 examples for class: Tim_Henman
# >loaded 1 examples for class: Eric_Lindros
# >loaded 1 examples for class: Brad_Brownell
# >loaded 4 examples for class: Carson_Palmer
# >loaded 2 examples for class: Mel_Brooks
# >loaded 1 examples for class: Craig_MacTavish
# >loaded 1 examples for class: James_Kirtley
# >loaded 1 examples for class: Claudia_Coslovich
# >loaded 1 examples for class: Scott_Blum
# >loaded 4 examples for class: Rebekah_Chantay_Revels
# >loaded 4 examples for class: Sally_Kirkland
# >loaded 1 examples for class: Ted_Costa
# >loaded 1 examples for class: Curtis_Joseph
# >loaded 4 examples for class: Helen_Clark
# >loaded 1 examples for class: Paul_Bettany
# >loaded 1 examples for class: Mary_Lou_Markakis
# >loaded 1 examples for class: Steven_Van_Zandt
# >loaded 2 examples for class: Miroljub
# >loaded 1 examples for class: James_Wattana
# >loaded 1 examples for class: Tom_Brennan
# >loaded 1 examples for class: Joanne_Woodward
# >loaded 2 examples for class: Dorthy_Moxley
# >loaded 1 examples for class: Luis_Gonzalez
# >loaded 1 examples for class: Alfredo_Moreno
# >loaded 1 examples for class: Suh_Young-hoon
# >loaded 1 examples for class: Jeremy_Gompertz
# >loaded 1 examples for class: Bob_Newhart
# >loaded 2 examples for class: Mike_Brey
# >loaded 2 examples for class: Jane_Fonda
# >loaded 5 examples for class: Sourav_Ganguly
# >loaded 4 examples for class: Tim_Allen
# >loaded 1 examples for class: Marian_Dolan
# >loaded 5 examples for class: Pamela_Anderson
# >loaded 3 examples for class: Milo_Maestrecampo
# >loaded 1 examples for class: James_Coviello
# >loaded 1 examples for class: Kevin_Tarrant
# >loaded 1 examples for class: Mohammad_Mustapha_Miro
# >loaded 1 examples for class: Jim_Otto
# >loaded 2 examples for class: Tony_Curtis
# >loaded 6 examples for class: Fujio_Cho
# >loaded 2 examples for class: Gerardo_Gambala
# >loaded 1 examples for class: Scott_Dalton
# >loaded 2 examples for class: Stan_Heath
# >loaded 1 examples for class: Abel_Aguilar
# >loaded 12 examples for class: Adrien_Brody
# >loaded 1 examples for class: Carla_Gay_Balingit
# >loaded 1 examples for class: LeRoy_Millette_Jr
# >loaded 1 examples for class: William_Genego
# >loaded 1 examples for class: George_Harrison
# >loaded 1 examples for class: Li_Ruihuan
# >loaded 3 examples for class: Hans_Eichel
# >loaded 2 examples for class: Marie-Reine_Le_Gougne
# >loaded 1 examples for class: Kenneth_Dam
# >loaded 1 examples for class: Fernando_Sanz
# >loaded 1 examples for class: Jason_Campbell
# >loaded 1 examples for class: Brett_Boone
# >loaded 2 examples for class: Mike_Holmgren
# >loaded 1 examples for class: Mohammad_Fares
# >loaded 1 examples for class: Eddie_Lewis
# >loaded 8 examples for class: Shimon_Peres
# >loaded 1 examples for class: Bela_Karolyi
# >loaded 2 examples for class: Albrecht_Mentz
# >loaded 1 examples for class: Geraldo_Rivera
# >loaded 1 examples for class: Hermes_Gamonal
# >loaded 1 examples for class: Steve_Nesbitt
# >loaded 2 examples for class: Scott_McNealy
# >loaded 1 examples for class: Alfonso_Portillo
# >loaded 1 examples for class: Romeo_Gigli
# >loaded 2 examples for class: Silvio_Fernandez
# >loaded 1 examples for class: Natalia_Verbeke
# >loaded 1 examples for class: Gil_Cates
# >loaded 1 examples for class: Dennis_Miller
# >loaded 41 examples for class: Lleyton_Hewitt
# >loaded 1 examples for class: Michael_Arif
# >loaded 1 examples for class: Larry_Harris
# >loaded 4 examples for class: Glafcos_Clerides
# >loaded 1 examples for class: Martin_Torrijos
# >loaded 7 examples for class: Al_Sharpton
# >loaded 3 examples for class: Robert_Bonner
# >loaded 2 examples for class: Michelle_Branch
# >loaded 1 examples for class: Brett_Hawke
# >loaded 1 examples for class: Askar_Akayev
# >loaded 1 examples for class: Gilberto_Simoni
# >loaded 1 examples for class: Stuart_Whitman
# >loaded 1 examples for class: Mother_Teresa
# >loaded 1 examples for class: Zurab_Tsereteli
# >loaded 1 examples for class: Harland_Braun
# >loaded 1 examples for class: Judd_Davies
# >loaded 2 examples for class: Bruce_Weber
# >loaded 15 examples for class: Taha_Yassin_Ramadan
# >loaded 1 examples for class: Rachel_Wadsworth
# >loaded 1 examples for class: Bonnie_Hunt
# >loaded 1 examples for class: Henry_Hilow
# >loaded 1 examples for class: Evan_Marriott
# >loaded 2 examples for class: Theo_Epstein
# >loaded 1 examples for class: Hana_Sadiq
# >loaded 1 examples for class: Brian_Williams
# >loaded 1 examples for class: Doug_Christie
# >loaded 2 examples for class: Andrew_Cuomo
# >loaded 1 examples for class: Richard_Paul_Evans
# >loaded 1 examples for class: Joel_Todd
# >loaded 1 examples for class: Ed_Wade
# >loaded 2 examples for class: Edward_Norton
# >loaded 1 examples for class: Rich_Brooks
# >loaded 1 examples for class: Matt_Morris
# >loaded 1 examples for class: Kelsey_Grammer
# >loaded 1 examples for class: Roger_Daltrey
# >loaded 1 examples for class: Dave_Johnson
# >loaded 1 examples for class: Elliott_Mincberg
# >loaded 1 examples for class: Nicola_Bono
# >loaded 2 examples for class: Mike_Montgomery
# >loaded 1 examples for class: Frank_Shea
# >loaded 1 examples for class: Ryan_Nyquist
# >loaded 3 examples for class: Bono
# >loaded 14 examples for class: Dick_Cheney
# >loaded 1 examples for class: Ed_Mekertichian
# >loaded 1 examples for class: Raul_Chacon
# >loaded 2 examples for class: Robert_Mugabe
# >loaded 1 examples for class: Mitchell_Crooks
# >loaded 2 examples for class: Joe_Mantello
# >loaded 1 examples for class: Wayne_Allard
# >loaded 1 examples for class: Joan_Dangerfield
# >loaded 1 examples for class: William_Cocksedge
# >loaded 3 examples for class: Warren_Buffett
# >loaded 1 examples for class: Wolfgang_Schwarz
# >loaded 1 examples for class: Princess_Hisako
# >loaded 2 examples for class: John_Wolf
# >loaded 1 examples for class: Christine_Rau
# >loaded 2 examples for class: Jean-Claude_Braquet
# >loaded 13 examples for class: Salma_Hayek
# >loaded 1 examples for class: Nick_Rahall
# >loaded 1 examples for class: John_Wayne
# >loaded 2 examples for class: Tom_Coverdale
# >loaded 1 examples for class: Stipe_Mesic
# >loaded 2 examples for class: Neri_Marcore
# >loaded 3 examples for class: Doris_Roberts
# >loaded 1 examples for class: Paul_Brandt
# >loaded 11 examples for class: Jiri_Novak
# >loaded 3 examples for class: Tubby_Smith
# >loaded 1 examples for class: Gianni_Agnelli
# >loaded 1 examples for class: Spike_Lee
# >loaded 2 examples for class: Jessica_Lange
# >loaded 2 examples for class: Brian_Griese
# >loaded 1 examples for class: Roberto_Laratro
# >loaded 3 examples for class: Gus_Van_Sant
# >loaded 2 examples for class: Svetlana_Koroleva
# >loaded 1 examples for class: Felix_Trinidad
# >loaded 7 examples for class: Robert_Zoellick
# >loaded 1 examples for class: Brendan_Gaughan
# >loaded 1 examples for class: Jafar_Umar_Thalib
# >loaded 24 examples for class: Atal_Bihari_Vajpayee
# >loaded 1 examples for class: Christopher_Conyers
# >loaded 1 examples for class: Liu_Xiaoqing
# >loaded 1 examples for class: Vadim_Devyatovskiy
# >loaded 1 examples for class: Takenori_Kanzaki
# >loaded 1 examples for class: Chris_Simon
# >loaded 1 examples for class: Momcilo_Perisic
# >loaded 1 examples for class: Naomi_Hayashi
# >loaded 2 examples for class: Larry_Johnson
# >loaded 2 examples for class: Job_Cohen
# >loaded 1 examples for class: Paul_Greengrass
# >loaded 2 examples for class: Simon_Cowell
# >loaded 1 examples for class: Jimmy_Smits
# >loaded 1 examples for class: Steve_Shiver
# >loaded 2 examples for class: Kathleen_Glynn
# >loaded 1 examples for class: Kim_Dong-hwa
# >loaded 1 examples for class: Queen_Silvia
# >loaded 1 examples for class: Omar_el-Heib
# >loaded 3 examples for class: Ray_Allen
# >loaded 2 examples for class: Rogerio_Romero
# >loaded 3 examples for class: Constance_Marie
# >loaded 1 examples for class: Giovanny_Cordoba
# >loaded 5 examples for class: Nia_Vardalos
# >loaded 1 examples for class: Ulrich_Kueperkoch
# >loaded 5 examples for class: George_Lopez
# >loaded 2 examples for class: Brian_Cowen
# >loaded 1 examples for class: Gunilla_Backman
# >loaded 3 examples for class: Vincent_Gallo
# >loaded 2 examples for class: Bruce_Van_De_Velde
# >loaded 4 examples for class: Lisa_Marie_Presley
# >loaded 4 examples for class: Janet_Napolitano
# >loaded 1 examples for class: Robin_McGraw
# >loaded 3 examples for class: Steve_Mariucci
# >loaded 1 examples for class: Ted_Washington
# >loaded 2 examples for class: Hilmi_Ozkok
# >loaded 1 examples for class: Aaron_Tippin
# >loaded 2 examples for class: Robert_Fico
# >loaded 1 examples for class: Jose_Luis_Chilavert
# >loaded 1 examples for class: Narayan_Singh_Pun
# >loaded 5 examples for class: Alastair_Campbell
# >loaded 1 examples for class: Cherry_Jones
# >loaded 2 examples for class: Ernesto_Zedillo
# >loaded 1 examples for class: Jamie_Kellner
# >loaded 1 examples for class: Carlos_Paternina
# >loaded 1 examples for class: Angie_Arzola
# >loaded 1 examples for class: Jeff_Feldman
# >loaded 1 examples for class: Harvey_Wachsman
# >loaded 1 examples for class: Maria_Burks
# >loaded 2 examples for class: Ken_Watanabe
# >loaded 2 examples for class: James_Smith
# >loaded 2 examples for class: Saburo_Kawabuchi
# >loaded 1 examples for class: Robert_Nardelli
# >loaded 1 examples for class: Sherry_Irving
# >loaded 2 examples for class: Jesse_James_Leija
# >loaded 1 examples for class: Rien_Long
# >loaded 3 examples for class: Ben_Curtis
# >loaded 1 examples for class: Frank_Murkowski
# >loaded 1 examples for class: Thomas_Van_Essen
# >loaded 2 examples for class: Chung_Mong-joon
# >loaded 1 examples for class: Muffet_McGraw
# >loaded 1 examples for class: Paul_LeClerc
# >loaded 1 examples for class: Robert_Wagner
# >loaded 2 examples for class: Jorge_Castaneda
# >loaded 1 examples for class: Jean-Rene_Fourtou
# >loaded 1 examples for class: Jason_Bentley
# >loaded 1 examples for class: Chuck_Eidson
# >loaded 1 examples for class: Herb_Dhaliwal
# >loaded 3 examples for class: Matt_Dillon
# >loaded 2 examples for class: Oleksandr_Moroz
# >loaded 1 examples for class: Mia_Mottley
# >loaded 3 examples for class: Melanie_Griffith
# >loaded 13 examples for class: Charles_Moose
# >loaded 1 examples for class: Lorraine_Fenton
# >loaded 1 examples for class: Raja_Ramani
# >loaded 1 examples for class: Bruce_Paltrow
# >loaded 1 examples for class: Chip_Knight
# >loaded 1 examples for class: Diana_Ross
# >loaded 1 examples for class: Scott_Hamilton
# >loaded 1 examples for class: Aishwarya_Rai
# >loaded 2 examples for class: Alberto_Fujimori
# >loaded 4 examples for class: Tim_Duncan
# >loaded 1 examples for class: Stephen_Silas
# >loaded 1 examples for class: Kyoko_Nakayama
# >loaded 1 examples for class: Charles_Richardson
# >loaded 1 examples for class: Oliver_Phelps
# >loaded 1 examples for class: Marquis_Estill
# >loaded 1 examples for class: Rosalie_Perkov
# >loaded 8 examples for class: Richard_Virenque
# >loaded 2 examples for class: Paul_William_Hurley
# >loaded 1 examples for class: Jeff_Weaver
# >loaded 1 examples for class: Dinora_Rosales
# >loaded 1 examples for class: Luis_Fonsi
# >loaded 1 examples for class: Steven_Tyler
# >loaded 1 examples for class: Jim_Haslett
# >loaded 1 examples for class: Tatiana_Gratcheva
# >loaded 1 examples for class: Rick_Husband
# >loaded 1 examples for class: Tom_Koenigs
# >loaded 1 examples for class: Carlos_Barragan
# >loaded 1 examples for class: Jack_Smith
# >loaded 1 examples for class: Linda_Lingle
# >loaded 1 examples for class: Michael_Donovan
# >loaded 2 examples for class: Reggie_Miller
# >loaded 1 examples for class: Tatiana_Shchegoleva
# >loaded 1 examples for class: Maggie_Cheung
# >loaded 1 examples for class: Todd_Reid
# >loaded 1 examples for class: Michael_Milton
# >loaded 1 examples for class: Alex_Cabrera
# >loaded 1 examples for class: Angel_Lockward
# >loaded 1 examples for class: Sasha_Cohen
# >loaded 1 examples for class: Bryan_Thomas
# >loaded 3 examples for class: Al_Pacino
# >loaded 3 examples for class: Johnny_Tapia
# >loaded 1 examples for class: Mark_Leno
# >loaded 1 examples for class: Taylyn_Solomon
# >loaded 1 examples for class: Chris_Cookson
# >loaded 1 examples for class: Nelson_Acosta
# >loaded 1 examples for class: Diana_Renee_Valdivieso_Dubon
# >loaded 1 examples for class: Clare_Latimer
# >loaded 1 examples for class: Joe_Leonard
# >loaded 2 examples for class: Thomas_Birmingham
# >loaded 3 examples for class: Ronald_Reagan
# >loaded 1 examples for class: David_Oh
# >loaded 1 examples for class: Alain_Cervantes
# >loaded 1 examples for class: Mickey_Gilley
# >loaded 1 examples for class: Carla_Sullivan
# >loaded 1 examples for class: Beyonce_Knowles
# >loaded 1 examples for class: Barry_Bonds
# >loaded 5 examples for class: Enrique_Bolanos
# >loaded 3 examples for class: Erik_Morales
# >loaded 1 examples for class: Mireya_Elisa_Moscoso_Rodriguez
# >loaded 2 examples for class: Richard_Shelby
# >loaded 1 examples for class: Patrick_Kron
# >loaded 1 examples for class: Bobby_Bowden
# >loaded 2 examples for class: Martin_Sheen
# >loaded 1 examples for class: Toni_Jennings
# >loaded 14 examples for class: Britney_Spears
# >loaded 1 examples for class: Roy_Rogers
# >loaded 3 examples for class: Matt_Doherty
# >loaded 1 examples for class: David_Ho
# >loaded 1 examples for class: Clint_Howard
# >loaded 1 examples for class: Svetoslav_Todorov
# >loaded 1 examples for class: Sven_Goran_Eriksson
# >loaded 1 examples for class: Julie_Infante
# >loaded 1 examples for class: Prospero_Pichay
# >loaded 1 examples for class: Janet_Leigh
# >loaded 1 examples for class: Giulio_Andreotti
# >loaded 7 examples for class: Elton_John
# >loaded 1 examples for class: Craig_Morgan
# >loaded 1 examples for class: Keith_Olbermann
# >loaded 4 examples for class: Vanessa_Incontrada
# >loaded 1 examples for class: Pascal_Affi_Nguessan
# >loaded 1 examples for class: Hashan_Tillakaratne
# >loaded 1 examples for class: Gerard_Kleisterlee
# >loaded 1 examples for class: Betty_Williams
# >loaded 1 examples for class: Anton_Balasingham
# >loaded 1 examples for class: Bill_Clancy
# >loaded 1 examples for class: Suzie_McConnell_Serio
# >loaded 4 examples for class: Gilberto_Rodriguez_Orejuela
# >loaded 5 examples for class: Donald_Rumsfeld
# >loaded 3 examples for class: Julia_Tymoshenko
# >loaded 4 examples for class: Raoul_Ruiz
# >loaded 1 examples for class: Barry_Diller
# >loaded 1 examples for class: Evgeni_Plushenko
# >loaded 1 examples for class: Nida_Blanca
# >loaded 1 examples for class: Chris_Columbus
# >loaded 1 examples for class: Kirsten_Dunst
# >loaded 1 examples for class: Ben_Chandler
# >loaded 3 examples for class: Eileen_Coparropa
# >loaded 3 examples for class: Gwendal_Peizerat
# >loaded 1 examples for class: Joshua_Perper
# >loaded 2 examples for class: Richard_Crenna
# >loaded 1 examples for class: Sonja_Kesselschlager
# >loaded 2 examples for class: Suzanne_Gaudet
# >loaded 1 examples for class: Maria_Guida
# >loaded 1 examples for class: Alexandra_Jackson
# >loaded 1 examples for class: Amber_Frey
# >loaded 3 examples for class: Thierry_Falise
# >loaded 1 examples for class: Dot_Helms
# >loaded 1 examples for class: Quincy_Jones
# >loaded 2 examples for class: Joe_Dumars
# >loaded 1 examples for class: Ronald_Perelman
# >loaded 1 examples for class: Alek_Wek
# >loaded 1 examples for class: Teresa_Graves
# >loaded 2 examples for class: Damon_van_Dam
# >loaded 1 examples for class: El_Hadji_Diouf
# >loaded 1 examples for class: Ted_Turner
# >loaded 3 examples for class: Michael_Ballack
# >loaded 4 examples for class: Queen_Beatrix
# >loaded 1 examples for class: John_Norquist
# >loaded 1 examples for class: Jerome_Golmard
# >loaded 1 examples for class: Ari_Bousbib
# >loaded 3 examples for class: Sadie_Frost
# >loaded 1 examples for class: Howard_Wilkinson
# >loaded 1 examples for class: David_Braley
# >loaded 6 examples for class: Diana_Krall
# >loaded 2 examples for class: Thomas_Wyman
# >loaded 1 examples for class: Ben_Cahoon
# >loaded 1 examples for class: Dorothy_Wilson
# >loaded 1 examples for class: Roger_Machado
# >loaded 1 examples for class: Ben_Cohen
# >loaded 1 examples for class: Saeed_Anwar
# >loaded 2 examples for class: Ricardo_Monasterio
# >loaded 1 examples for class: Feliciano_Lopez
# >loaded 1 examples for class: Joey_Mantia
# >loaded 1 examples for class: Derian_Hatcher
# >loaded 3 examples for class: Placido_Domingo
# >loaded 1 examples for class: Juan_Francisco_Palencia
# >loaded 1 examples for class: Jack_Valenti
# >loaded 1 examples for class: Hubert_Green
# >loaded 1 examples for class: Zakia_Hakki
# >loaded 1 examples for class: Gerrit_Zalm
# >loaded 1 examples for class: Bart_Hendricks
# >loaded 1 examples for class: Hartmut_Mehdorn
# >loaded 1 examples for class: Aparna_Pillai
# >loaded 1 examples for class: Isidro_Pastor
# >loaded 2 examples for class: Doug_Duncan
# >loaded 1 examples for class: Laurent_Woulzy
# >loaded 1 examples for class: Ruth_Christofferson
# >loaded 1 examples for class: Stephane_Rousseau
# >loaded 5 examples for class: Oswaldo_Paya
# >loaded 1 examples for class: Lesia_Burlak
# >loaded 3 examples for class: Monica_Lewinsky
# >loaded 2 examples for class: Torri_Edwards
# >loaded 1 examples for class: Javier_Delgado
# >loaded 6 examples for class: Thaksin_Shinawatra
# >loaded 1 examples for class: Juan_Roman_Riquelme
# >loaded 1 examples for class: Wan_Yanhai
# >loaded 1 examples for class: Larry_Campbell
# >loaded 1 examples for class: Laurie_Chan
# >loaded 1 examples for class: Isabel_Orellana
# >loaded 1 examples for class: Tina_Andrews
# >loaded 1 examples for class: Garry_Alejano
# >loaded 2 examples for class: Begum_Khaleda_Zia
# >loaded 1 examples for class: Chris_Matthews
# >loaded 1 examples for class: Raja_Qureshi
# >loaded 4 examples for class: Sila_Calderon
# >loaded 3 examples for class: Victoria_Beckham
# >loaded 2 examples for class: Vince_Gill
# >loaded 1 examples for class: Bruno_Junquiera
# >loaded 2 examples for class: Gloria_Allred
# >loaded 1 examples for class: Emma_Nicholson
# >loaded 8 examples for class: Gerry_Adams
# >loaded 8 examples for class: Antonio_Palocci
# >loaded 1 examples for class: Herb_Ritts
# >loaded 4 examples for class: Marc_Grossman
# >loaded 2 examples for class: Pat_Cox
# >loaded 1 examples for class: Randy_Johnson
# >loaded 1 examples for class: Larry_Wilmore
# >loaded 3 examples for class: Alex_Sink
# >loaded 1 examples for class: Jonathan_Arden
# >loaded 3 examples for class: Elena_Bovina
